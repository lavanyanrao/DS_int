# %%
# importing necessary libraries
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# Question 4

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.flipkart.com/")

# %%
# input sunglasses in the search field
search_job = driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input") 
search_job.send_keys("Redmi note 9")

# %%
# closing the login intimation
close_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
close_btn.click()

# %%
# clicking on the search button
search_btn = driver.find_element_by_xpath("//button[@class='L0Z3Pu']") 
search_btn.click()

# %%
Brand =[]
Name=[]
Colour = []
RAM =[]
ROM =[]
Primary_camera=[]
Display=[]
Processor = []
Battery=[]
Price=[]
Url = []

# %%
url = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for i in url:
    Url.append(i.get_attribute('href'))

# %%
bncr = driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in bncr:
    Brand.append(i.text.split()[0])
    Name.append(i.text.split()[1]+i.text.split()[2])
    Colour.append(i.text.split('(')[1].split(',')[0])
    ROM.append(i.text.split(',')[1])

# %%
ram = driver.find_elements_by_xpath("//li[@class='rgWa7D'][1]")
for i in ram:
    RAM.append(i.text.split()[0]+i.text.split()[1])

# %%
display = driver.find_elements_by_xpath("//li[@class='rgWa7D'][2]")
for i in display:
    Display.append(i.text)

# %%
battery = driver.find_elements_by_xpath("//li[@class='rgWa7D'][4]")
for i in battery:
    Battery.append(i.text)

# %%
processor = driver.find_elements_by_xpath("//li[@class='rgWa7D'][5]")
Processor.append(processor[1].text)
for i in processor[3:8]:
    Processor.append(i.text)
for i in processor[9:]:
    Processor.append(i.text)
Processor[0:0]='-'
Processor[2:2]='-'
Processor[8:8]='-'

# %%
price = driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")
for i in price:
    Price.append(i.text)

# %%
d4 = pd.DataFrame({'Brand':Brand,
                  'Name':Name,
                  'RAM':RAM,
                  'ROM':ROM,
                  'Color':Colour,
                  'Display':Display,
                  'Battery':Battery,
                  'Processor':Processor,
                  'Price':Price,
                  'Url':Url})
d4
# Out:
#     Brand    Name  RAM       ROM               Color  \
# 0   Redmi   Note9  4GB    64 GB)         Scarlet Red
# 1   Redmi   Note9  4GB    64 GB)        Arctic White
# 2   Redmi   Note9  4GB   128 GB)         Scarlet Red
# 3   Redmi   Note9  4GB    64 GB)         Pebble Grey
# 4   Redmi   Note9  6GB   128 GB)          Aqua Green
# 5   Redmi   Note9  4GB   128 GB)          Aqua Green
# 6   Redmi   Note9  4GB    64 GB)          Aqua Green
# 7   Redmi   Note9  6GB   128 GB)         Pebble Grey
# 8   Redmi   Note9  6GB   128 GB)         Scarlet Red
# 9   Redmi   Note9  4GB   128 GB)         Pebble Grey
# 10  Redmi   Note9  4GB    64 GB)        Shadow Black
# 11  Redmi  9Prime  4GB    64 GB)         Matte Black
# 12  Redmi   Note9  6GB    64 GB)  Interstellar Black
# 13  Redmi   Note9  6GB   128 GB)        Shadow Black
# 14  Redmi   Note9  6GB   128 GB)        Arctic White
# 15  Redmi   Note9  4GB   128 GB)        Arctic White
# 16  Redmi   Note9  4GB   128 GB)        Shadow Black
# ...

# %%
driver.close()

# %% [markdown]
# Qusetion 3

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://images.google.com")

# %%
# typing 'fruits' in the search bar
search= driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search.send_keys('fruits')

# %%
# clicking the search button
btn = driver.find_element_by_xpath("//button[@class='Tg7LZd']")
btn.click()

# %%
# retriving the image url
Fruits=[]
fruits = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
for i in fruits[0:100]:
    Fruits.append(i.get_attribute('src'))

# %%
# clearing the previuos input and searching for cars
search= driver.find_element_by_xpath("//input[@class='JSAgYe']")
search.clear()
search.send_keys('cars')

# %%
# clicking the button
btn = driver.find_element_by_xpath("//button[@class='KXJfe']")
btn.click()

# %%
# retriving the image url
Cars=[]
cars = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
for i in cars[0:100]:
    Cars.append(i.get_attribute('src'))

# %%
# searching for images on machine learning
search= driver.find_element_by_xpath("//input[@class='JSAgYe']")
search.clear()
search.send_keys('machine learning')

# %%
# clicking the button
btn = driver.find_element_by_xpath("//button[@class='KXJfe']")
btn.click()

# %%
# retriving the image url
ML=[]
ml = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
for i in ml[0:100]:
    ML.append(i.get_attribute('src'))

# %%
d2 = pd.DataFrame({'Fruits':Fruits,'Cars':Cars,'Machine_Learning':ML})
d2
# Out:
#                                                Fruits  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                                  Cars  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                      Machine_Learning
# 0   ......
# ...

# %%
driver.close()

# %% [markdown]
# Question 6

# %%
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
Date=[]
Name=[]
Type=[]
Sub_verticle=[]
City=[]
Investors_name=[]
Investment_type=[]
Amount=[]

# %%
date = driver.find_elements_by_xpath("//td[@class='column-2']")
for i in date[34:64]:
    Date.append(i.text)

# %%
name = driver.find_elements_by_xpath("//td[@class='column-3']")
for i in name[34:64]:
    Name.append(i.text)

# %%
type = driver.find_elements_by_xpath("//td[@class='column-4']")
for i in type[34:64]:
    Type.append(i.text)

# %%
sub_verticle = driver.find_elements_by_xpath("//td[@class='column-5']")
for i in sub_verticle[34:64]:
    Sub_verticle.append(i.text)

# %%
city = driver.find_elements_by_xpath("//td[@class='column-6']")
for i in city[34:64]:
    City.append(i.text)

# %%
investors = driver.find_elements_by_xpath("//td[@class='column-7']")
for i in investors[34:64]:
    Investors_name.append(i.text)

# %%
investment = driver.find_elements_by_xpath("//td[@class='column-8']")
for i in investment[34:64]:
    Investment_type.append(i.text)

# %%
amount = driver.find_elements_by_xpath("//td[@class='column-9']")
for i in amount[34:64]:
    Amount.append(i.text)

# %%
sept_nxt = driver.find_elements_by_xpath("//a[@class='paginate_button next']")
sept_nxt[1].click()

# %%
aug_nxt = driver.find_elements_by_xpath("//a[@class='paginate_button next']")
aug_nxt[1].click()

# %%
date = driver.find_elements_by_xpath("//td[@class='column-2']")
for i in date[34:37]:
    Date.append(i.text)

name = driver.find_elements_by_xpath("//td[@class='column-3']")
for i in name[34:37]:
    Name.append(i.text)
    
type = driver.find_elements_by_xpath("//td[@class='column-4']")
for i in type[34:37]:
    Type.append(i.text)
    
sub_verticle = driver.find_elements_by_xpath("//td[@class='column-5']")
for i in sub_verticle[34:37]:
    Sub_verticle.append(i.text)
    
city = driver.find_elements_by_xpath("//td[@class='column-6']")
for i in city[34:37]:
    City.append(i.text)
    
investors = driver.find_elements_by_xpath("//td[@class='column-7']")
for i in investors[34:37]:
    Investors_name.append(i.text)
    
investment = driver.find_elements_by_xpath("//td[@class='column-8']")
for i in investment[34:37]:
    Investment_type.append(i.text)
    
amount = driver.find_elements_by_xpath("//td[@class='column-9']")
for i in amount[34:37]:
    Amount.append(i.text)

# %%
d6 = pd.DataFrame({'Date':Date,'Company_name':Name,'Verticle':Type,'Sub_verticle':Sub_verticle,'City':City,'Investors_name':Investors_name,'Investment_type':Investment_type,'Amount':Amount})
d6
# Out:
#           Date               Company_name  \
# 0   08/09/2020                     Byju’s
# 1   12/09/2020                  mCaffeine
# 2   09/09/2020                     Qshala
# 3   02/09/2020                      Winzo
# 4   09/09/2020                Hippo Video
# 5   07/09/2020                    Melorra
# 6   07/09/2020                        1mg
# 7   31/08/2020                      mfine
# 8   31/08/2020                       Apna
# 9   03/09/2020                    Railofy
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  15/07/2020                   Flipkart
# ...

# %%
driver.close()

# %% [markdown]
# Question 5

# %%
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.google.com/maps/")

# %%
search_box = driver.find_element_by_id("searchboxinput")
search_box.send_keys("Vijayanagara")

# %%
search_btn = driver.find_element_by_id("searchbox-searchbutton")
search_btn.click()

# %%
url=[]
coordinates = driver.find_element_by_css_selector('meta[itemprop=image]')
url.append(coordinates.get_attribute('content'))
url
# Out:
# ['https://maps.google.com/maps/api/staticmap?center=15.01726045%2C76.31887315&zoom=7&size=256x256&language=en&sensor=false&client=google-maps-frontend&signature=llS1ff2DQa_NLbKC4stKSvHfdYw']

# %%
Coordinates = url[0].split('?center=')[1].split('&zoom=')[0].split('%2C')
Coordinates
# Out:
# ['15.01726045', '76.31887315']

# %%
driver.close()

# %% [markdown]
# Question 7

# %%
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
OS=[]
Display=[]
Processor = []
Memory = []
Weight = []
Dimension = []
Graphics = []
Name = []
Price = []

# %%
os = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
for i in os:
    OS.append(i.text)

# %%
display = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
for i in display:
    Display.append(i.text)

# %%
processor = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
for i in processor:
    Processor.append(i.text)

# %%
memory = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
for i in memory:
    Memory.append(i.text)

# %%
weight = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
for i in weight:
    Weight.append(i.text)

# %%
dimension = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
for i in dimension:
    Dimension.append(i.text)

# %%
graphics = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
for i in graphics:
    Graphics.append(i.text)

# %%
name = driver.find_elements_by_xpath("//a/h3")
for i in name:
    Name.append(i.text)

# %%
for i in range(2,12):
    price = driver.find_elements_by_xpath(f"//table[@id ='summtable']/tbody/tr[{i}]/td[3]")
    Price.append(price[0].text)

# %%
d7 = pd.DataFrame({'Product_name':Name,'OS':OS,'Display':Display,'Processor':Processor,'Memory':Memory,'Weight':Weight,'Dimension':Dimension,'Graphics_processor':Graphics,'Price':Price})
d7
# Out:
#                 Product_name                      OS  \
# 0      MSI GT76 TITAN DT 9SG          Windows 10 Pro
# 1      ALIENWARE 17 AREA-51M          Windows 10 Pro
# 2            HP OMEN 15 2020         Windows 10 Home
# 3          ASUS ZEPHYRUS G14         Windows 10 Home
# 4         LENOVO LEGION Y540         Windows 10 Home
# 5  ASUS ROG ZEPHYRUS G GA502         Windows 10 Home
# 6  ASUS ROG ZEPHYRUS S GX531         Windows 10 Home
# 7   MSI GT83VR 7RE TITAN SLI  Windows 10 Home 64 bit
# 8   ASUS ROG ZEPHYRUS DUO 15              Windows 10
# 9                    DELL G3    Windows 10 Home Plus
#
#                      Display  \
# 0      17.3" (UHD 3840x2160)
# 1  17.3" (FHD (1920 x 1080))
# 2        15.6" (1920 x 1080)
# 3          14" (1920 x 1080)
# 4        15.6" (1920 X 1080)
# 5        15.6" (1920 x 1080)
# 6        15.6" (1920 X 1080)
# 7        18.4" (1920 x 1080)
# 8        15.6" (3840 x 1100)
# 9               15.6 MP | NA
#
# ...

# %%
driver.close()

# %% [markdown]
# Questions 1 and 2

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.amazon.in/")

# %%
# entering watches in the search field
search = driver.find_element_by_xpath("//div[@class='nav-search-field ']/input")
search.send_keys("mobile")

# %%
#clicking the search button
search_btn = driver.find_element_by_id("nav-search-submit-button")
search_btn.click()

# %%
Brand=[]
Name=[]
Rating=[]
No_of_rating = []
Price = []
Delivery = []
Other_details = []

# %%
bno = driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in bno:
    Brand.append(i.text.split()[0])
    Name.append(i.text.split()[1]+i.text.split()[2])
    Other_details.append(i.text.split('(')[1])

# %%
print(len(Brand))
print(len(Name))
print(len(Other_details))
# Out:
# 22
# 22
# 22

# %%
rating = driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span[1]")
for i in rating[0:5]:
    Rating.append(i.get_attribute('aria-label'))
for i in rating[9:]:
    Rating.append(i.get_attribute('aria-label'))

# %%
nrating = driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span[2]")
for i in nrating[0:5]:
    No_of_rating.append(i.get_attribute('aria-label'))
for i in nrating[9:]:
    No_of_rating.append(i.get_attribute('aria-label'))

# %%
print(len(No_of_rating))
print(len(Rating))
# Out:
# 22
# 22

# %%
price = driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in price[0:5]:
    Price.append(i.text)
for i in price[9:]:
    Price.append(i.text)

# %%
len(Price)
# Out:
# 22

# %%
delivery = driver.find_elements_by_xpath("//span[@class='a-text-bold']")
for i in delivery:
    Delivery.append(i.text)
Delivery[9:9]='-'
Delivery[13:13]='-'

# %%
len(Delivery)
# Out:
# 22

# %%
nxt_btn = driver.find_element_by_xpath("//li[@class='a-last']")
nxt_btn.click()

# %%
# 2nd page

bno = driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in bno:
    Brand.append(i.text.split()[0])
    Name.append(i.text.split()[1]+i.text.split()[2])
    Other_details.append(i.text.split('(')[1])
print(len(Brand))
print(len(Name))
print(len(Other_details))

rating = driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span[1]")
for i in rating:
    Rating.append(i.get_attribute('aria-label'))
Rating[13:13]='-'
print(len(Rating))

nrating = driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span[2]")
for i in nrating:
    No_of_rating.append(i.get_attribute('aria-label'))
No_of_rating[13:13]='-'
print(len(No_of_rating))

price = driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in price:
    Price.append(i.text)
Price[7:7]='-'
print(len(Price))

delivery = driver.find_elements_by_xpath("//span[@class='a-text-bold']")
for i in delivery:
    Delivery.append(i.text)
Delivery[7:7]='-'
Delivery[12:12]='-'
print(len(Delivery))
# Out:
# 44
# 44
# 44
# 44
# 44
# 44
# 44

# %%
nxt_btn = driver.find_element_by_xpath("//li[@class='a-last']")
nxt_btn.click()

# %%
# 3rd page

bno = driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in bno:
    Brand.append(i.text.split()[0])
    Name.append(i.text.split()[1]+i.text.split()[2])
    Other_details.append(i.text.split('(')[1])
print(len(Brand))
print(len(Name))
print(len(Other_details))

rating = driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span[1]")
for i in rating:
    Rating.append(i.get_attribute('aria-label'))
Rating[6:6]='-'
print(len(Rating))

nrating = driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span[2]")
for i in nrating:
    No_of_rating.append(i.get_attribute('aria-label'))
No_of_rating[6:6]='-'
print(len(No_of_rating))

price = driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in price:
    Price.append(i.text)
Price[18:18]='-'
print(len(Price))

delivery = driver.find_elements_by_xpath("//span[@class='a-text-bold']")
for i in delivery:
    Delivery.append(i.text)
Delivery[18:18]='-'
Delivery[15:15]='-'
print(len(Delivery))
# Out:
# 66
# 66
# 66
# 66
# 66
# 66
# 66

# %%
d12 = pd.DataFrame({'Brand':Brand,
                   'Name':Name,
                   'Rating':Rating,
                   'No_of_rating':No_of_rating,
                   'Price':Price,
                   'Delivery':Delivery,
                   'Other_details':Other_details})
d12
# Out:
#       Brand         Name              Rating No_of_rating   Price  \
# 0   Samsung    GalaxyM51  4.4 out of 5 stars       31,072  22,999
# 1   Samsung    GalaxyM02  3.7 out of 5 stars          862   7,499
# 2     Redmi        9(Sky  4.0 out of 5 stars       11,389   8,799
# 3     Redmi    9A(Nature  4.1 out of 5 stars       13,911   6,799
# 4   Samsung    GalaxyM01  3.4 out of 5 stars        9,227   5,999
# ..      ...          ...                 ...          ...     ...
# 61   Lenovo    A7(Black,  3.1 out of 5 stars           55  29,999
# 62    Redmi       9A(Sea  4.1 out of 5 stars       13,911   7,955
# 63     itel      A47(Ice  4.7 out of 5 stars           11   5,499
# 64  Samsung    GalaxyM02  3.7 out of 5 stars          862   6,999
# 65      New  AppleiPhone  4.3 out of 5 stars          582  66,900
#
#               Delivery                                      Other_details
# 0    Tomorrow, March 1             Electric Blue, 6GB RAM, 128GB Storage)
# ...

# %%
driver.close()
